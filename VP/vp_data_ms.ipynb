# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
fct_ms=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교시설 개방에 관한 사항(중)_서울특별시교육청.csv")

# %%
fct_ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교      3
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교      3
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교      3
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교      3
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교      3
# ..        ...             ...         ...         ...             ...    ...
# 382  서울특별시교육청    서울특별시남부교육지원청   서울특별시 구로구  S010006401           항동중학교      3
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교      3
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교      3
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교      3
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교      3
#
# ...

# %%
fct_ms = fct_ms[['지역','학교명','설립구분','체육관 개방여부']]

# %%
fct_ms
# Out:
#              지역             학교명 설립구분 체육관 개방여부
# 0     서울특별시 강남구           개원중학교   공립        무
# 1     서울특별시 서초구           경원중학교   공립        무
# 2     서울특별시 강남구           구룡중학교   공립        무
# 3     서울특별시 강남구          압구정중학교   공립        무
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립     시설없음
# ..          ...             ...  ...      ...
# 382   서울특별시 구로구           항동중학교   공립     시설없음
# 383  서울특별시 영등포구           신길중학교   공립     시설없음
# 384   서울특별시 강서구         마곡하늬중학교   공립        유
# 385   서울특별시 송파구          해누리중학교   공립        무
# 386   서울특별시 강동구           강빛중학교   공립        유
#
# [387 rows x 4 columns]

# %%
ms=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교 현황(중)_서울특별시교육청.csv")
ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교      3
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교      3
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교      3
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교      3
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교      3
# ..        ...             ...         ...         ...             ...    ...
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교      3
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교      3
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교      3
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교      3
# 387  서울특별시교육청    서울특별시서부교육지원청   서울특별시 마포구  S010006282  아현중학교부설방송통신중학교     25
#
# ...

# %%
ms = ms[['지역','학교명','설립구분','학생수(계)']]
ms
# Out:
#              지역             학교명 설립구분   학생수(계)
# 0     서울특별시 강남구           개원중학교   공립  896(19)
# 1     서울특별시 서초구           경원중학교   공립  1056(6)
# 2     서울특별시 강남구           구룡중학교   공립   784(6)
# 3     서울특별시 강남구          압구정중학교   공립   428(0)
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립   606(0)
# ..          ...             ...  ...      ...
# 383  서울특별시 영등포구           신길중학교   공립  704(11)
# 384   서울특별시 강서구         마곡하늬중학교   공립   662(0)
# 385   서울특별시 송파구          해누리중학교   공립   658(7)
# 386   서울특별시 강동구           강빛중학교   공립   263(2)
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립   308(0)
#
# [388 rows x 4 columns]

# %%
test_df=fct_ms.merge(ms,how='outer')
test_df
# Out:
#              지역             학교명 설립구분 체육관 개방여부   학생수(계)
# 0     서울특별시 강남구           개원중학교   공립        무  896(19)
# 1     서울특별시 서초구           경원중학교   공립        무  1056(6)
# 2     서울특별시 강남구           구룡중학교   공립        무   784(6)
# 3     서울특별시 강남구          압구정중학교   공립        무   428(0)
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립     시설없음   606(0)
# ..          ...             ...  ...      ...      ...
# 383  서울특별시 영등포구           신길중학교   공립     시설없음  704(11)
# 384   서울특별시 강서구         마곡하늬중학교   공립        유   662(0)
# 385   서울특별시 송파구          해누리중학교   공립        무   658(7)
# 386   서울특별시 강동구           강빛중학교   공립        유   263(2)
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립      NaN   308(0)
#
# [388 rows x 5 columns]

# %%
info_ms=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교기본정보(중)_서울특별시교육청.csv")
info_ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교      3
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교      3
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교      3
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교      3
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교      3
# ..        ...             ...         ...         ...             ...    ...
# 382  서울특별시교육청    서울특별시남부교육지원청   서울특별시 구로구  S010006401           항동중학교      3
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교      3
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교      3
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교      3
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교      3
#
# ...

# %%
info_ms[info_ms.지역=='서울특별시 동대문구']
# Out:
#         시도교육청         지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 145  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001363         경희여자중학교      3
# 146  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001364           경희중학교      3
# 147  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001365           대광중학교      3
# 148  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001367  동국대학교사범대학부속중학교      3
# 149  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001368          동대문중학교      3
# 154  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001373           성일중학교      3
# 156  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001375           숭인중학교      3
# 162  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001381           장평중학교      3
# 163  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001382           전농중학교      3
# 164  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001383           전동중학교      3
# 165  서울특별시교육청  서울특별시동부교육지원청  서울특별시 동대문구  S010001384           전일중학교      3
# ...

# %%
info_ms=info_ms[['지역','학교명','설립구분','학교특성','위도','경도','남녀공학 구분']]
info_ms
# Out:
#              지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분
# 0     서울특별시 강남구           개원중학교   공립   NaN  37.491641  127.071415    남녀공학
# 1     서울특별시 서초구           경원중학교   공립   NaN  37.510997  127.008879    남녀공학
# 2     서울특별시 강남구           구룡중학교   공립   NaN  37.486153  127.056123    남녀공학
# 3     서울특별시 강남구          압구정중학교   공립   NaN  37.530239  127.032986    남녀공학
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립   NaN  37.495336  127.056494       남
# ..          ...             ...  ...   ...        ...         ...     ...
# 382   서울특별시 구로구           항동중학교   공립   NaN  37.482748  126.820242    남녀공학
# 383  서울특별시 영등포구           신길중학교   공립   NaN  37.501890  126.915523    남녀공학
# 384   서울특별시 강서구         마곡하늬중학교   공립   NaN  37.558007  126.820861    남녀공학
# 385   서울특별시 송파구          해누리중학교   공립   NaN  37.498364  127.101956    남녀공학
# 386   서울특별시 강동구           강빛중학교   공립   NaN  37.573938  127.170899    남녀공학
#
# [387 rows x 7 columns]

# %%
info_ms=info_ms.merge(test_df, how='outer')
info_ms
# Out:
#              지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 0     서울특별시 강남구           개원중학교   공립   NaN  37.491641  127.071415    남녀공학
# 1     서울특별시 서초구           경원중학교   공립   NaN  37.510997  127.008879    남녀공학
# 2     서울특별시 강남구           구룡중학교   공립   NaN  37.486153  127.056123    남녀공학
# 3     서울특별시 강남구          압구정중학교   공립   NaN  37.530239  127.032986    남녀공학
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립   NaN  37.495336  127.056494       남
# ..          ...             ...  ...   ...        ...         ...     ...
# 383  서울특별시 영등포구           신길중학교   공립   NaN  37.501890  126.915523    남녀공학
# 384   서울특별시 강서구         마곡하늬중학교   공립   NaN  37.558007  126.820861    남녀공학
# 385   서울특별시 송파구          해누리중학교   공립   NaN  37.498364  127.101956    남녀공학
# 386   서울특별시 강동구           강빛중학교   공립   NaN  37.573938  127.170899    남녀공학
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립   NaN        NaN         NaN     NaN
#
#     체육관 개방여부   학생수(계)
# 0          무  896(19)
# 1          무  1056(6)
# ...

# %%
#전체 중학교 중 체육관을 개방학는 학교 수 = 153
info_ms[info_ms['체육관 개방여부']=='유']
# Out:
#             지역      학교명 설립구분  학교특성         위도          경도 남녀공학 구분 체육관 개방여부  \
# 7    서울특별시 강남구    대청중학교   공립   NaN  37.490430  127.058351    남녀공학        유
# 13   서울특별시 강남구    봉은중학교   공립   NaN  37.518941  127.062120    남녀공학        유
# 19   서울특별시 강남구    수서중학교   공립   NaN  37.491204  127.102379    남녀공학        유
# 23   서울특별시 서초구   신반포중학교   공립   NaN  37.505955  126.995829    남녀공학        유
# 25   서울특별시 서초구    언남중학교   공립   NaN  37.472406  127.044412    남녀공학        유
# ..         ...      ...  ...   ...        ...         ...     ...      ...
# 377  서울특별시 강서구    마곡중학교   공립   NaN  37.567983  126.821401    남녀공학        유
# 379  서울특별시 강남구    세곡중학교   공립   NaN  37.471542  127.092201    남녀공학        유
# 380  서울특별시 송파구    송례중학교   공립   NaN  37.477883  127.139596    남녀공학        유
# 384  서울특별시 강서구  마곡하늬중학교   공립   NaN  37.558007  126.820861    남녀공학        유
# 386  서울특별시 강동구    강빛중학교   공립   NaN  37.573938  127.170899    남녀공학        유
#
#        학생수(계)
# 7     1080(0)
# 13     288(0)
# 19    507(11)
# ...

# %%
#전체 중학교 중 체육관을 개방하는 학교의 비율
(info_ms[info_ms['체육관 개방여부']=='유'].count().학교명/387*100).round(1)
# Out:
# 39.5

# %%
# 체육관을 개방하는 학교와 개방하지 않는 학교의 수 계산
gym_open_schools = (info_ms['체육관 개방여부'] == '유').sum()
gym_closed_schools = (info_ms['체육관 개방여부'] == '무').sum()
non_public_gym_schools = (info_ms['체육관 개방여부'] == '시설없음').sum()

# 원 그래프 그리기
labels = ['체육관 개방', '체육관 미개방', '체육관 없음']
sizes = [gym_open_schools, gym_closed_schools, non_public_gym_schools]
colors = ['lightskyblue', 'lightcoral', 'grey']
explode = (0.1, 0, 0)  # 체육관 개방 부분을 약간 돌출

plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # 원을 원형으로 표시

# 그래프 출력
plt.title('체육관 개방 학교 비율')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50977 (\N{HANGUL SYLLABLE YUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
ms_fd=info_ms.groupby('설립구분')

# %%
info_ms.설립구분.unique()
#공립=279, 사립=109
279/388
# Out:
# 0.7190721649484536

# %%
# 전체 학교 중 공립학교의 비율 계산
total_schools = len(info_ms)  # 전체 학교 개수
public_schools = (info_ms['설립구분'] == '공립').sum()  # 공립학교 개수

public_school_ratio = public_schools / total_schools  # 공립학교 비율 계산

print(f"전체 학교 중 공립학교의 비율: {public_school_ratio:.2%}")
# Out:
# 전체 학교 중 공립학교의 비율: 71.91%

# %%
# '설립구분' 열을 기준으로 공립학교와 사립학교의 개수 계산
school_counts = info_ms['설립구분'].value_counts()

# 원 그래프를 그릴 데이터 준비
labels = school_counts.index  # 학교 유형 (공립, 사립)
sizes = school_counts.values  # 개수

# 원 그래프 그리기
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=120,colors=['orange','royalblue'])
plt.title('중학교 설립구분 비율')
plt.axis('equal')  # 원 그래프를 원형으로 유지

# 그래프 표시
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47549 (\N{HANGUL SYLLABLE RIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
ms_pb=ms_fd.get_group('공립')
ms_pb
# Out:
#              지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 0     서울특별시 강남구           개원중학교   공립   NaN  37.491641  127.071415    남녀공학
# 1     서울특별시 서초구           경원중학교   공립   NaN  37.510997  127.008879    남녀공학
# 2     서울특별시 강남구           구룡중학교   공립   NaN  37.486153  127.056123    남녀공학
# 3     서울특별시 강남구          압구정중학교   공립   NaN  37.530239  127.032986    남녀공학
# 5     서울특별시 강남구           대명중학교   공립   NaN  37.506056  127.061064    남녀공학
# ..          ...             ...  ...   ...        ...         ...     ...
# 383  서울특별시 영등포구           신길중학교   공립   NaN  37.501890  126.915523    남녀공학
# 384   서울특별시 강서구         마곡하늬중학교   공립   NaN  37.558007  126.820861    남녀공학
# 385   서울특별시 송파구          해누리중학교   공립   NaN  37.498364  127.101956    남녀공학
# 386   서울특별시 강동구           강빛중학교   공립   NaN  37.573938  127.170899    남녀공학
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립   NaN        NaN         NaN     NaN
#
#     체육관 개방여부   학생수(계)
# 0          무  896(19)
# 1          무  1056(6)
# ...

# %%
ms_pb[ms_pb['체육관 개방여부']=='유'].count().지역
# Out:
# 138

# %%
#공립 중학교 중 체육관 개방 학교 비율
ms_pb_rt=(ms_pb[ms_pb['체육관 개방여부']=='유'].count().지역)/(ms_pb.count().iloc[0])*100
ms_pb_rt.round(1)
# Out:
# 49.5

# %%
# 공립학교 중에서 체육관을 개방하는 학교와 개방하지 않는 학교의 수 계산
public_gym_open_schools = ((info_ms['설립구분'] == '공립') & (info_ms['체육관 개방여부'] == '유')).sum()
public_gym_closed_schools = ((info_ms['설립구분'] == '공립') & (info_ms['체육관 개방여부'] == '무')).sum()
non_public_gym_schools = ((info_ms['설립구분'] == '공립') & (info_ms['체육관 개방여부'] == '시설없음')).sum()

# 원 그래프 그리기
labels = ['체육관 개방', '체육관 미개방', '체육관 없음']
sizes = [public_gym_open_schools, public_gym_closed_schools, non_public_gym_schools]
colors = ['lightskyblue', 'lightcoral','grey']
explode = (0.1, 0, 0.)  # 체육관 개방 부분을 약간 돌출

plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # 원을 원형으로 표시

# 그래프 출력
plt.title('공립학교 중 체육관 개방 학교 비율')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47549 (\N{HANGUL SYLLABLE RIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
ms_pv=ms_fd.get_group('사립')
ms_pv
# Out:
#             지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 4    서울특별시 강남구  단국대학교사범대학부속중학교   사립   NaN  37.495336  127.056494       남
# 10   서울특별시 서초구         동덕여자중학교   사립   NaN  37.475918  126.992753       녀
# 14   서울특별시 서초구         서문여자중학교   사립   NaN  37.488770  126.984628       녀
# 18   서울특별시 서초구         세화여자중학교   사립   NaN  37.501991  126.994265       녀
# 20   서울특별시 강남구         숙명여자중학교   사립   NaN  37.491474  127.052612       녀
# ..         ...             ...  ...   ...        ...         ...     ...
# 341  서울특별시 용산구           오산중학교   사립   NaN  37.523974  126.999569       남
# 345   서울특별시 중구           장충중학교   사립   NaN  37.553109  127.006169       남
# 346  서울특별시 종로구           중앙중학교   사립   NaN  37.586097  126.986677    남녀공학
# 350   서울특별시 중구           한양중학교   사립   NaN  37.565719  127.010857       남
# 351   서울특별시 중구           환일중학교   사립   NaN  37.553861  126.961937       남
#
#     체육관 개방여부  학생수(계)
# 4       시설없음  606(0)
# 10      시설없음  448(0)
# 14      시설없음  627(0)
# ...

# %%
ms_pv[ms_pv['체육관 개방여부']=='유'].count()
# Out:
# 지역          15
# 학교명         15
# 설립구분        15
# 학교특성         0
# 위도          15
# 경도          15
# 남녀공학 구분     15
# 체육관 개방여부    15
# 학생수(계)      15
# dtype: int64

# %%
#사립 중학교 중 체육관 개방 학교 비율
ms_pv_rt=(ms_pv[ms_pv['체육관 개방여부']=='유'].count().지역)/(ms_pv.count().iloc[0])*100
ms_pv_rt.round(1)
# Out:
# 13.8

# %%
# 사립학교 중에서 체육관을 개방하는 학교와 개방하지 않는 학교의 수 계산
private_gym_open_schools = ((info_ms['설립구분'] == '사립') & (info_ms['체육관 개방여부'] == '유')).sum()
private_gym_closed_schools = ((info_ms['설립구분'] == '사립') & (info_ms['체육관 개방여부'] == '무')).sum()
non_private_gym_schools =  ((info_ms['설립구분'] == '사립') & (info_ms['체육관 개방여부'] == '시설없음')).sum()

# 원 그래프 그리기
labels = ['체육관 개방', '체육관 미개방', '체육관 없음']
sizes = [private_gym_open_schools, private_gym_closed_schools, non_private_gym_schools]
colors = ['lightskyblue', 'lightcoral', 'grey']
explode = (0.1, 0, 0)  # 체육관 개방 부분을 약간 돌출

plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # 원을 원형으로 표시

# 그래프 출력
plt.title('사립학교 중 체육관 개방 학교 비율')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47549 (\N{HANGUL SYLLABLE RIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
info_ms[info_ms.지역=='서울특별시 동대문구']
# Out:
#              지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 145  서울특별시 동대문구         경희여자중학교   사립   NaN  37.594562  127.051427       녀
# 146  서울특별시 동대문구           경희중학교   사립   NaN  37.594487  127.054904       남
# 147  서울특별시 동대문구           대광중학교   사립   NaN  37.578519  127.024809    남녀공학
# 148  서울특별시 동대문구  동국대학교사범대학부속중학교   사립   NaN  37.578048  127.075134       남
# 149  서울특별시 동대문구          동대문중학교   공립   NaN  37.574509  127.052094    남녀공학
# 154  서울특별시 동대문구           성일중학교   공립   NaN  37.581852  127.033851    남녀공학
# 156  서울특별시 동대문구           숭인중학교   공립   NaN  37.573920  127.044058    남녀공학
# 162  서울특별시 동대문구           장평중학교   공립   NaN  37.566861  127.070477    남녀공학
# 163  서울특별시 동대문구           전농중학교   공립   NaN  37.582043  127.059279    남녀공학
# 164  서울특별시 동대문구           전동중학교   공립   NaN  37.585817  127.070928    남녀공학
# 165  서울특별시 동대문구           전일중학교   공립   NaN  37.581818  127.058463    남녀공학
# 166  서울특별시 동대문구         정화여자중학교   사립   NaN  37.585632  127.040543       녀
# ...

# %%
info_ms
# Out:
#              지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 0     서울특별시 강남구           개원중학교   공립   NaN  37.491641  127.071415    남녀공학
# 1     서울특별시 서초구           경원중학교   공립   NaN  37.510997  127.008879    남녀공학
# 2     서울특별시 강남구           구룡중학교   공립   NaN  37.486153  127.056123    남녀공학
# 3     서울특별시 강남구          압구정중학교   공립   NaN  37.530239  127.032986    남녀공학
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립   NaN  37.495336  127.056494       남
# ..          ...             ...  ...   ...        ...         ...     ...
# 383  서울특별시 영등포구           신길중학교   공립   NaN  37.501890  126.915523    남녀공학
# 384   서울특별시 강서구         마곡하늬중학교   공립   NaN  37.558007  126.820861    남녀공학
# 385   서울특별시 송파구          해누리중학교   공립   NaN  37.498364  127.101956    남녀공학
# 386   서울특별시 강동구           강빛중학교   공립   NaN  37.573938  127.170899    남녀공학
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립   NaN        NaN         NaN     NaN
#
#     체육관 개방여부   학생수(계)
# 0          무  896(19)
# 1          무  1056(6)
# ...

# %%
info_ms[info_ms.iloc[:,-3]=='녀']
# Out:
#              지역               학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 10    서울특별시 서초구           동덕여자중학교   사립   NaN  37.475918  126.992753       녀
# 14    서울특별시 서초구           서문여자중학교   사립   NaN  37.488770  126.984628       녀
# 18    서울특별시 서초구           세화여자중학교   사립   NaN  37.501991  126.994265       녀
# 20    서울특별시 강남구           숙명여자중학교   사립   NaN  37.491474  127.052612       녀
# 34    서울특별시 강남구           진선여자중학교   사립   NaN  37.502310  127.048286       녀
# 53    서울특별시 강동구             상일중학교   사립   NaN  37.547954  127.170218       녀
# 56    서울특별시 강동구           성덕여자중학교   사립   NaN  37.549597  127.141637       녀
# 63    서울특별시 송파구           영파여자중학교   사립   NaN  37.532854  127.120354       녀
# 67    서울특별시 송파구           일신여자중학교   사립   NaN  37.500880  127.113224       녀
# 70    서울특별시 송파구           정신여자중학교   사립   NaN  37.509454  127.073848       녀
# 86    서울특별시 강서구           명덕여자중학교   사립   NaN  37.553625  126.834815       녀
# ...

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

from matplotlib import font_manager, rc

import platform

if platform.system()=="Windows":

    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()

    rc('font', family=font_name)

matplotlib.rcParams['axes.unicode_minus']=False



import warnings

warnings.filterwarnings("ignore")

# %%
# 지역별로 그룹화하고 학교 수 계산
school_counts = info_ms['지역'].value_counts()

# 그래프 그리기
plt.figure(figsize=(12, 6))
school_counts.plot(kind='bar', color='skyblue')
plt.title('지역별 학교 수')
plt.xlabel('지역')
plt.ylabel('학교 수')
plt.xticks(rotation=45)
plt.tight_layout()

# 그래프 출력
plt.show()

# %%
# 지역별로 그룹화하고 체육관 개방 비율 계산
grouped = info_ms.groupby('지역')
total_schools = grouped.size()
gym_open_schools = grouped['체육관 개방여부'].apply(lambda x: (x == '유').sum())
gym_open_ratio = (gym_open_schools / total_schools) * 100

# 그래프 그리기
plt.figure(figsize=(12, 6))
gym_open_ratio.sort_values(ascending=False).plot(kind='bar', color='pink')
plt.title('지역별 체육관 개방 비율')
plt.xlabel('지역')
plt.ylabel('체육관 개방 비율 (%)')
plt.xticks(rotation=45)
plt.tight_layout()

# 그래프 출력
plt.show()

# %%
grouped.size()
# Out:
# 지역
# 서울특별시 강남구     23
# 서울특별시 강동구     19
# 서울특별시 강북구     13
# 서울특별시 강서구     22
# 서울특별시 관악구     16
# 서울특별시 광진구     12
# 서울특별시 구로구     14
# 서울특별시 금천구      9
# 서울특별시 노원구     26
# 서울특별시 도봉구     13
# 서울특별시 동대문구    15
# 서울특별시 동작구     16
# 서울특별시 마포구     15
# 서울특별시 서대문구    14
# 서울특별시 서초구     16
# 서울특별시 성동구     11
# 서울특별시 성북구     17
# 서울특별시 송파구     29
# 서울특별시 양천구     19
# 서울특별시 영등포구    12
# 서울특별시 용산구      9
# 서울특별시 은평구     18
# 서울특별시 종로구      8
# 서울특별시 중구       8
# 서울특별시 중랑구     14
# dtype: int64

# %%
gym_open_schools
# Out:
# 지역
# 서울특별시 강남구      8
# 서울특별시 강동구      5
# 서울특별시 강북구      6
# 서울특별시 강서구      8
# 서울특별시 관악구      8
# 서울특별시 광진구      5
# 서울특별시 구로구      8
# 서울특별시 금천구      5
# 서울특별시 노원구     11
# 서울특별시 도봉구      5
# 서울특별시 동대문구     1
# 서울특별시 동작구      7
# 서울특별시 마포구      8
# 서울특별시 서대문구     8
# 서울특별시 서초구      4
# 서울특별시 성동구      3
# 서울특별시 성북구      5
# 서울특별시 송파구     13
# 서울특별시 양천구     12
# 서울특별시 영등포구     7
# 서울특별시 용산구      2
# 서울특별시 은평구      6
# 서울특별시 종로구      0
# 서울특별시 중구       2
# 서울특별시 중랑구      6
# Name: 체육관 개방여부, dtype: int64

# %%
# 지역별로 그룹화하고 학교 수와 체육관 개방 비율 계산
grouped = info_ms.groupby('지역')
total_schools = grouped.size()
gym_open_schools = grouped['체육관 개방여부'].apply(lambda x: (x == '유').sum())
gym_open_ratio = (gym_open_schools / total_schools) * 100

# 그래프 그리기
plt.figure(figsize=(12, 6))
plt.bar(total_schools.index, total_schools, color='skyblue', label='학교 수')
plt.plot(gym_open_ratio.index, gym_open_ratio, marker='o', color='orange', label='체육관 개방 비율')

plt.title('지역별 학교 수 및 체육관 개방 비율')
plt.xlabel('지역')
plt.ylabel('학교 수 / 체육관 개방 비율 (%)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()

# 그래프 출력
plt.show()

# %%
# 데이터를 '지역' 열로 그룹화하고 각 그룹의 학교 수와 체육관 개방 학교 수를 계산
grouped = info_ms.groupby('지역')
total_schools_per_region = grouped.size()
gyms_open_per_region = grouped['체육관 개방여부'].apply(lambda x: (x == '유').sum())

# 지역별 체육관 개방 비율 계산
gym_open_ratio_per_region = gyms_open_per_region / total_schools_per_region

# 스택형(bar) 그래프 그리기
plt.figure(figsize=(12, 6))
p1 = plt.bar(total_schools_per_region.index, total_schools_per_region, color='skyblue', label='전체 학교 수')
p2 = plt.bar(gyms_open_per_region.index, gyms_open_per_region, color='lightgreen', label='체육관 개방 학교 수')
plt.ylabel('학교 수')
plt.xlabel('지역')
plt.title('서울시 자치구별 학교 수 및 체육관 개방 학교 비율')
# x축 라벨을 공백 뒤의 글자만 표시
plt.xticks(range(len(total_schools_per_region)), [label.split()[-1] for label in total_schools_per_region.index], rotation=45)
plt.legend((p1[0], p2[0]), ('전체 학교 수', '체육관 개방 학교 수'))

# 막대 그래프 위에 숫자로 체육관 개방 비율 나타내기
for i, v in enumerate(gym_open_ratio_per_region):
    plt.text(i, v * total_schools_per_region[i], f'{v:.2f}', ha='center', va='bottom')


# 그래프 출력
plt.show()

# %%
info_ms[info_ms['지역']=='서울특별시 동대문구']
# Out:
#              지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 145  서울특별시 동대문구         경희여자중학교   사립   NaN  37.594562  127.051427       녀
# 146  서울특별시 동대문구           경희중학교   사립   NaN  37.594487  127.054904       남
# 147  서울특별시 동대문구           대광중학교   사립   NaN  37.578519  127.024809    남녀공학
# 148  서울특별시 동대문구  동국대학교사범대학부속중학교   사립   NaN  37.578048  127.075134       남
# 149  서울특별시 동대문구          동대문중학교   공립   NaN  37.574509  127.052094    남녀공학
# 154  서울특별시 동대문구           성일중학교   공립   NaN  37.581852  127.033851    남녀공학
# 156  서울특별시 동대문구           숭인중학교   공립   NaN  37.573920  127.044058    남녀공학
# 162  서울특별시 동대문구           장평중학교   공립   NaN  37.566861  127.070477    남녀공학
# 163  서울특별시 동대문구           전농중학교   공립   NaN  37.582043  127.059279    남녀공학
# 164  서울특별시 동대문구           전동중학교   공립   NaN  37.585817  127.070928    남녀공학
# 165  서울특별시 동대문구           전일중학교   공립   NaN  37.581818  127.058463    남녀공학
# 166  서울특별시 동대문구         정화여자중학교   사립   NaN  37.585632  127.040543       녀
# ...

# %%
info_ms[info_ms['지역']=='서울특별시 금천구'].count()
# Out:
# 지역          9
# 학교명         9
# 설립구분        9
# 학교특성        0
# 위도          9
# 경도          9
# 남녀공학 구분     9
# 체육관 개방여부    9
# 학생수(계)      9
# dtype: int64

# %%
# 학생 수 비율로 추가
 
    데이터 수집 어려움
     # 연도별로 전체 개방 비율(평균) 달라지는 추이 
     # 연도별로 학생 수(평균) 달라지는 추이
    ok # 설립구분 별로 개방 비율 평균



    남녀공학 
    지도
    # 상관분석
    # https://eunhye-zz.tistory.com/29 ### 범주형 - 연속형 간 상관관계 분석
   유의미한분석불가-  학생수 규모에 따른 체육관 개방여부 상관관계 
                    종로구 --- 설립일 - 체육관 개방여부 상관관계

    ok # 라벨 표시

고교 분석, 중고 비교
    # 추가 데이터 --------- 학교 시설 개방의 역사
    
    # 구 별로 인구 그래프
# 구 별로 체육 시설 갯수 그래프
# Out:
#   File <tokenize>:14
#     유의미한분석불가-  학생수 규모에 따른 체육관 개방여부 상관관계
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
info_ms
# Out:
#              지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 0     서울특별시 강남구           개원중학교   공립   NaN  37.491641  127.071415    남녀공학
# 1     서울특별시 서초구           경원중학교   공립   NaN  37.510997  127.008879    남녀공학
# 2     서울특별시 강남구           구룡중학교   공립   NaN  37.486153  127.056123    남녀공학
# 3     서울특별시 강남구          압구정중학교   공립   NaN  37.530239  127.032986    남녀공학
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립   NaN  37.495336  127.056494       남
# ..          ...             ...  ...   ...        ...         ...     ...
# 383  서울특별시 영등포구           신길중학교   공립   NaN  37.501890  126.915523    남녀공학
# 384   서울특별시 강서구         마곡하늬중학교   공립   NaN  37.558007  126.820861    남녀공학
# 385   서울특별시 송파구          해누리중학교   공립   NaN  37.498364  127.101956    남녀공학
# 386   서울특별시 강동구           강빛중학교   공립   NaN  37.573938  127.170899    남녀공학
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립   NaN        NaN         NaN     NaN
#
#     체육관 개방여부   학생수(계)
# 0          무  896(19)
# 1          무  1056(6)
# ...

# %%
# 남녀공학 구분별로 그룹화
grouped = info_ms.groupby('남녀공학 구분')

# 각 그룹의 크기 계산
group_sizes = grouped.size()

# 원 그래프로 비율 표현
plt.figure(figsize=(8, 8))
explode = (0.01,0.01,0.01)
plt.pie(group_sizes, labels=group_sizes.index, autopct='%1.1f%%', startangle=140, explode=explode,colors = ['royalblue','orchid', 'tomato'])
plt.title('남녀공학 구분 비율')
plt.axis('equal')  # 원 그래프를 원형으로 표현하기 위해 필요
plt.show()

# %%
# 남학교만 선택
male_schools = info_ms[info_ms['남녀공학 구분'] == '남']

# 체육관 개방 여부 카운트
counted = male_schools['체육관 개방여부'].value_counts()
explode = (0.01,0.01,0.01)
# 원 그래프로 비율 표현
plt.figure(figsize=(8, 8))
plt.pie(counted, labels=counted.index, autopct='%1.1f%%', startangle=140,explode=explode, colors = ['grey','green', 'orange'])
plt.title('남학교 중 체육관 개방 여부 비율')
plt.axis('equal')  # 원 그래프를 원형으로 표현하기 위해 필요
plt.show()

# %%
# 여학교만 선택
female_schools = info_ms[info_ms['남녀공학 구분'] == '녀']

# 체육관 개방 여부 카운트
counted = female_schools['체육관 개방여부'].value_counts()
explode = (0.01,0.01,0.01)
# 원 그래프로 비율 표현
plt.figure(figsize=(8, 8))
plt.pie(counted, labels=counted.index, autopct='%1.1f%%', startangle=90,explode=explode,colors = ['grey','green', 'orange'])
plt.title('여학교 중 체육관 개방 여부 비율')

plt.axis('equal')  # 원 그래프를 원형으로 표현하기 위해 필요
plt.show()

# %%
# 남녀공학만 선택
male_schools = info_ms[info_ms['남녀공학 구분'] == '남녀공학']
explode = (0.01,0.01,0.01)
# 체육관 개방 여부 카운트
counted = male_schools['체육관 개방여부'].value_counts()
colors = ['green','orange', 'grey']
# 원 그래프로 비율 표현
plt.figure(figsize=(8, 8))
plt.pie(counted, labels=counted.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode)
plt.title('남녀공학 중 체육관 개방 여부 비율')
plt.legend(counted.index, loc="best")  # 범례를 그래프의 적절한 위치로 이동
plt.axis('equal')  # 원 그래프를 원형으로 표현하기 위해 필요
plt.show()

# %%
import plotly.express as px

# %%
# 필터링 조건에 맞는 학교 개수 계산
total_schools = len(info_ms)
filtered_schools = info_ms[(info_ms['남녀공학 구분'].isin(['남', '녀'])) & (info_ms['설립구분'] == '사립')]
filtered_schools_count = len(filtered_schools)

# 비율 계산
ratio = filtered_schools_count / total_schools

# 그래프 그리기
labels = ['사립', '기타']
sizes = [ratio, 1 - ratio]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # '사립' 부분을 약간 돌출

plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # 원을 원형으로 표시

# 그래프 출력
plt.title('남녀공학 구분이 "남" 또는 "녀"이면서 설립구분이 "사립"인 학교 비율')
plt.show()

# %%
# '학생수(계)' 열에서 괄호 안의 숫자를 제거하고 숫자로 변환
info_ms['학생수(계)'] = info_ms['학생수(계)'].str.extract('(\d+)').astype(int)
# 그래프 그리기

fig = px.scatter(
    info_ms, 
    x='학생수(계)', 
    y='체육관 개방여부', 
    color='체육관 개방여부', 
    text=None,  # 마우스를 대면 학교 이름 표시
    hover_data=['학교명'],
    title='학생 수에 따른 체육관 개방 여부 분포',
    color_discrete_map={'유': 'green', '무': 'red', '시설없음': 'yellow'},  # 색상 설정
)

# 그래프 출력
fig.show()
# Out:
# <div>                            <div id="6903f872-4687-4d93-8fe0-73d67f5803dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6903f872-4687-4d93-8fe0-73d67f5803dd")) {                    Plotly.newPlot(                        "6903f872-4687-4d93-8fe0-73d67f5803dd",                        [{"customdata":[["\uac1c\uc6d0\uc911\ud559\uad50"],["\uacbd\uc6d0\uc911\ud559\uad50"],["\uad6c\ub8e1\uc911\ud559\uad50"],["\uc555\uad6c\uc815\uc911\ud559\uad50"],["\ub300\uba85\uc911\ud559\uad50"],["\ub300\uc655\uc911\ud559\uad50"],["\ub300\uce58\uc911\ud559\uad50"],["\uc11c\uc6b4\uc911\ud559\uad50"],["\uc11c\uc77c\uc911\ud559\uad50"],["\uc2e0\uad6c\uc911\ud559\uad50"],["\uc2e0\ub3d9\uc911\ud559\uad50"],["\uc2e0\uc0ac\uc911\ud559\uad50"],["\uc5b8\ubd81\uc911\ud559
# ...

# %%
import json

# %%
import plotly.express as px

# 서울의 지도 데이터를 가져오는 코드 (예시)
# 서울 지도 데이터는 GeoJSON 형식이어야 합니다.
geojson_data = json.load(open('C:/Users/user/Downloads/SIG_Seoul.geojson', encoding='utf-8'))

# 학교 데이터프레임에서 필요한 열만 선택
school_data = info_ms[['학교명', '위도', '경도']]

# 서울 지도를 그립니다.
fig = px.scatter_geo(
    school_data,
    lat='위도',
    lon='경도',
    text='학교명',
    title='서울 지도에 학교 위치 표시',
)

# 그래프 출력
fig.update_geos(
    center=dict(lon=127.000, lat=37.500),  # 지도의 중심 위치 설정
    scope='asia',  # 지도 표시 범위 설정
)
fig.show()
# Out:
# <div>                            <div id="7f0db6a4-2adb-450e-8680-6597972cb540" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f0db6a4-2adb-450e-8680-6597972cb540")) {                    Plotly.newPlot(                        "7f0db6a4-2adb-450e-8680-6597972cb540",                        [{"geo":"geo","hovertemplate":"\ud559\uad50\uba85=%{text}<br>\uc704\ub3c4=%{lat}<br>\uacbd\ub3c4=%{lon}<extra></extra>","lat":[37.4916411882,37.510997,37.4861532953,37.5302391768,37.4953357,37.5060558822,37.4834565459,37.4904302007,37.4845654,37.4923472,37.4759176,37.5030706,37.494454,37.5189411,37.48877,37.493734,37.4985297674,37.485539216,37.5019914,37.4912039496,37.4914744604,37.527283,37.516699,37.505955,37.5246989184,37.4724059,37.5194271102,37.5144,37.495934
# ...

# %%
import folium

# %%
m = folium.Map(location=[37.55, 126.98], zoom_start=11)  # 서울을 중심으로 지도 생성

# %%
for index, row in info_ms.iterrows():
    school_name = row['학교명']
    latitude = row['위도']
    longitude = row['경도']
    gym_open = row['체육관 개방여부']
    
    # 위치 정보가 NaN인 행은 건너뜀
    if pd.notna(latitude) and pd.notna(longitude):
        # 체육관을 개방하는 학교는 파란색 점으로, 개방하지 않는 학교는 붉은색 점으로 표시
        if gym_open == '유':
            color = 'blue'
        else:
            color = 'red'
        
        # 마커 추가
        folium.Marker([latitude, longitude], tooltip=school_name, icon=folium.Icon(color=color)).add_to(m)

# 지도를 저장하거나 표시
m.save('school_map.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
info_ms
# Out:
#              지역             학교명 설립구분  학교특성         위도          경도 남녀공학 구분  \
# 0     서울특별시 강남구           개원중학교   공립   NaN  37.491641  127.071415    남녀공학
# 1     서울특별시 서초구           경원중학교   공립   NaN  37.510997  127.008879    남녀공학
# 2     서울특별시 강남구           구룡중학교   공립   NaN  37.486153  127.056123    남녀공학
# 3     서울특별시 강남구          압구정중학교   공립   NaN  37.530239  127.032986    남녀공학
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립   NaN  37.495336  127.056494       남
# ..          ...             ...  ...   ...        ...         ...     ...
# 383  서울특별시 영등포구           신길중학교   공립   NaN  37.501890  126.915523    남녀공학
# 384   서울특별시 강서구         마곡하늬중학교   공립   NaN  37.558007  126.820861    남녀공학
# 385   서울특별시 송파구          해누리중학교   공립   NaN  37.498364  127.101956    남녀공학
# 386   서울특별시 강동구           강빛중학교   공립   NaN  37.573938  127.170899    남녀공학
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립   NaN        NaN         NaN     NaN
#
#     체육관 개방여부  학생수(계)
# 0          무     896
# 1          무    1056
# ...

# %%
info_ms.경도.isna().sum()
# Out:
# 1
