# %% [markdown]
# 1. 시각화 프로젝트
# 데이터 수집 -> 전처리 -> 분석 -> 시각화
# 신문, 방송, 도서, 커뮤니티 데이터 수집
# 캐글, 데이콘, ai허브, data.go.kr, 공모전, 통계청, 학교 등
# 의료 데이터
# https://www.bigdata-covid.kr/
#
# - 주제 검색
# : 데이터 존재 유무
# - 가능한 주제인가? (주제 범위 설정)
# - 분석 목표 설정, 결과 해석

# %%
import numpy as np
import pandas as pd

# %%
import folium

# %%
fct_ms=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교시설 개방에 관한 사항(중)_서울특별시교육청.csv")

# %%
fct_ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교      3
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교      3
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교      3
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교      3
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교      3
# ..        ...             ...         ...         ...             ...    ...
# 382  서울특별시교육청    서울특별시남부교육지원청   서울특별시 구로구  S010006401           항동중학교      3
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교      3
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교      3
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교      3
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교      3
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
fct_ms['학교명'].nunique()
# Out:
# 387

# %%
fct_ms['학교명'].unique()
# Out:
# array(['개원중학교', '경원중학교', '구룡중학교', '압구정중학교', '단국대학교사범대학부속중학교', '대명중학교',
#        '대왕중학교', '대청중학교', '대치중학교', '도곡중학교', '동덕여자중학교', '반포중학교', '방배중학교',
#        '봉은중학교', '서문여자중학교', '서운중학교', '서일중학교', '서초중학교', '세화여자중학교', '수서중학교',
#        '숙명여자중학교', '신구중학교', '신동중학교', '신반포중학교', '신사중학교', '언남중학교', '언북중학교',
#        '언주중학교', '역삼중학교', '영동중학교', '원촌중학교', '은성중학교', '이수중학교', '중동중학교',
#        '진선여자중학교', '청담중학교', '휘문중학교', '가락중학교', '가원중학교', '강일중학교', '거원중학교',
#        '고덕중학교', '동북중학교', '동신중학교', '둔촌중학교', '명일중학교', '문정중학교', '방산중학교',
#        '방이중학교', '배명중학교', '배재중학교', '보성중학교', '보인중학교', '상일중학교', '석촌중학교',
#        '성내중학교', '성덕여자중학교', '세륜중학교', '송파중학교', '신명중학교', '신암중학교', '신천중학교',
#        '아주중학교', '영파여자중학교', '오금중학교', '오륜중학교', '오주중학교', '일신여자중학교', '잠신중학교',
#        '잠실중학교', '정신여자중학교', '천일중학교', '천호중학교', '풍납중학교', '풍성중학교', '한산중학교',
#        '한영중학교', '강신중학교', '경서중학교', '공항중학교', '금옥중학교', '덕원중학교', '등명중학교',
#        '등원중학교', '등촌중학교', '마포중학교', '명덕여자중학교', '목동중학교', '목일중학교', '방원중학교',
# ...

# %%
fct_ms = fct_ms[['지역','학교명','설립구분','체육관 개방여부']]

# %%
fct_ms
# Out:
#              지역             학교명 설립구분 체육관 개방여부
# 0     서울특별시 강남구           개원중학교   공립        무
# 1     서울특별시 서초구           경원중학교   공립        무
# 2     서울특별시 강남구           구룡중학교   공립        무
# 3     서울특별시 강남구          압구정중학교   공립        무
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립     시설없음
# ..          ...             ...  ...      ...
# 382   서울특별시 구로구           항동중학교   공립     시설없음
# 383  서울특별시 영등포구           신길중학교   공립     시설없음
# 384   서울특별시 강서구         마곡하늬중학교   공립        유
# 385   서울특별시 송파구          해누리중학교   공립        무
# 386   서울특별시 강동구           강빛중학교   공립        유
#
# [387 rows x 4 columns]

# %%
fct_ms['체육관 개방여부'].isna().sum()
# Out:
# 6

# %%
fct_hs=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교시설 개방에 관한 사항(고)_서울특별시교육청.csv")

# %%
fct_hs
# Out:
#         시도교육청     지역교육청          지역   정보공시 학교코드              학교명  학교급코드 설립구분  \
# 0    서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010000370           가락고등학교      4   공립
# 1    서울특별시교육청  서울특별시교육청   서울특별시 강동구  S010000371           강동고등학교      4   사립
# 2    서울특별시교육청  서울특별시교육청   서울특별시 양천구  S010000372           강서고등학교      4   사립
# 3    서울특별시교육청  서울특별시교육청   서울특별시 강남구  S010000373           개포고등학교      4   공립
# 4    서울특별시교육청  서울특별시교육청   서울특별시 광진구  S010000374  건국대학교사범대학부속고등학교      4   사립
# ..        ...       ...         ...         ...              ...    ...  ...
# 313  서울특별시교육청  서울특별시교육청  서울특별시 서대문구  S010005591          가재울고등학교      4   공립
# 314  서울특별시교육청  서울특별시교육청   서울특별시 은평구  S010005616           하나고등학교      4   사립
# 315  서울특별시교육청  서울특별시교육청   서울특별시 성동구  S010006381           금호고등학교      4   공립
# 316  서울특별시교육청  서울특별시교육청   서울특별시 성동구  S010006382           도선고등학교      4   공립
# 317  서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010006558      덕수고등학교(일반고)      4   공립
#
# ...

# %%
fct_hs['학교명'].nunique()
# Out:
# 318

# %%
ms1=ms.join(fct_ms, lsuffix='_1', how='outer')
ms1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ms1=ms.join(fct_ms, lsuffix='_1', how='outer')
#       2 ms1
#
# NameError: name 'ms' is not defined

# %%
pd.concat([ms,fct_ms],axis='columns').iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.concat([ms,fct_ms],axis='columns').iloc[0]
#
# NameError: name 'ms' is not defined

# %% [markdown]
# fct_hs,ms = 체육관 개방 정보, 학교명, 지역, 설립구분
# hs, ms = 학생수, 학교명, 지역, 설립구분
# info_hs,ms = 지역, 학교명, 설립구분, 학교특성, 위도, 경도, 남녀공학구분

# %%
ms=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교 현황(중)_서울특별시교육청.csv")
ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교      3
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교      3
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교      3
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교      3
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교      3
# ..        ...             ...         ...         ...             ...    ...
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교      3
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교      3
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교      3
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교      3
# 387  서울특별시교육청    서울특별시서부교육지원청   서울특별시 마포구  S010006282  아현중학교부설방송통신중학교     25
#
# ...

# %%
fct_ms
# Out:
#              지역             학교명 설립구분 체육관 개방여부
# 0     서울특별시 강남구           개원중학교   공립        무
# 1     서울특별시 서초구           경원중학교   공립        무
# 2     서울특별시 강남구           구룡중학교   공립        무
# 3     서울특별시 강남구          압구정중학교   공립        무
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립     시설없음
# ..          ...             ...  ...      ...
# 382   서울특별시 구로구           항동중학교   공립     시설없음
# 383  서울특별시 영등포구           신길중학교   공립     시설없음
# 384   서울특별시 강서구         마곡하늬중학교   공립        유
# 385   서울특별시 송파구          해누리중학교   공립        무
# 386   서울특별시 강동구           강빛중학교   공립        유
#
# [387 rows x 4 columns]

# %%
ms = ms[['지역','학교명','설립구분','학생수(계)']]

# %%
ms
# Out:
#              지역             학교명 설립구분   학생수(계)
# 0     서울특별시 강남구           개원중학교   공립  896(19)
# 1     서울특별시 서초구           경원중학교   공립  1056(6)
# 2     서울특별시 강남구           구룡중학교   공립   784(6)
# 3     서울특별시 강남구          압구정중학교   공립   428(0)
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립   606(0)
# ..          ...             ...  ...      ...
# 383  서울특별시 영등포구           신길중학교   공립  704(11)
# 384   서울특별시 강서구         마곡하늬중학교   공립   662(0)
# 385   서울특별시 송파구          해누리중학교   공립   658(7)
# 386   서울특별시 강동구           강빛중학교   공립   263(2)
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립   308(0)
#
# [388 rows x 4 columns]

# %%
test_df=fct_ms.merge(ms,how='outer',on=['지역','학교명','설립구분'])
test_df
# Out:
#              지역             학교명 설립구분 체육관 개방여부   학생수(계)
# 0     서울특별시 강남구           개원중학교   공립        무  896(19)
# 1     서울특별시 서초구           경원중학교   공립        무  1056(6)
# 2     서울특별시 강남구           구룡중학교   공립        무   784(6)
# 3     서울특별시 강남구          압구정중학교   공립        무   428(0)
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립     시설없음   606(0)
# ..          ...             ...  ...      ...      ...
# 383  서울특별시 영등포구           신길중학교   공립     시설없음  704(11)
# 384   서울특별시 강서구         마곡하늬중학교   공립        유   662(0)
# 385   서울특별시 송파구          해누리중학교   공립        무   658(7)
# 386   서울특별시 강동구           강빛중학교   공립        유   263(2)
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립      NaN   308(0)
#
# [388 rows x 5 columns]

# %%
info_ms=info_ms[['지역','학교명','설립구분','학교특성','위도','경도','남녀공학 구분']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 info_ms=info_ms[['지역','학교명','설립구분','학교특성','위도','경도','남녀공학 구분']]
#
# NameError: name 'info_ms' is not defined

# %%
info_ms=info_ms.merge(test_df, how='outer')
info_ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교    3.0
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교    3.0
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교    3.0
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교    3.0
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교    3.0
# ..        ...             ...         ...         ...             ...    ...
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교    3.0
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교    3.0
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교    3.0
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교    3.0
# 387       NaN             NaN   서울특별시 마포구         NaN  아현중학교부설방송통신중학교    NaN
#
# ...

# %%
test_df
# Out:
#              지역             학교명 설립구분 체육관 개방여부   학생수(계)
# 0     서울특별시 강남구           개원중학교   공립        무  896(19)
# 1     서울특별시 서초구           경원중학교   공립        무  1056(6)
# 2     서울특별시 강남구           구룡중학교   공립        무   784(6)
# 3     서울특별시 강남구          압구정중학교   공립        무   428(0)
# 4     서울특별시 강남구  단국대학교사범대학부속중학교   사립     시설없음   606(0)
# ..          ...             ...  ...      ...      ...
# 383  서울특별시 영등포구           신길중학교   공립     시설없음  704(11)
# 384   서울특별시 강서구         마곡하늬중학교   공립        유   662(0)
# 385   서울특별시 송파구          해누리중학교   공립        무   658(7)
# 386   서울특별시 강동구           강빛중학교   공립        유   263(2)
# 387   서울특별시 마포구  아현중학교부설방송통신중학교   공립      NaN   308(0)
#
# [388 rows x 5 columns]

# %%
test_df['체육관 개방여부'].isna().sum()
# Out:
# 7

# %%
fct_hs=fct_hs[['지역','학교명','설립구분','체육관 개방여부']]

# %%
fct_hs
# Out:
#              지역              학교명 설립구분 체육관 개방여부
# 0     서울특별시 송파구           가락고등학교   공립        무
# 1     서울특별시 강동구           강동고등학교   사립     시설없음
# 2     서울특별시 양천구           강서고등학교   사립     시설없음
# 3     서울특별시 강남구           개포고등학교   공립        무
# 4     서울특별시 광진구  건국대학교사범대학부속고등학교   사립        유
# ..          ...              ...  ...      ...
# 313  서울특별시 서대문구          가재울고등학교   공립        무
# 314   서울특별시 은평구           하나고등학교   사립        유
# 315   서울특별시 성동구           금호고등학교   공립        무
# 316   서울특별시 성동구           도선고등학교   공립     시설없음
# 317   서울특별시 송파구      덕수고등학교(일반고)   공립        무
#
# [318 rows x 4 columns]

# %%
hs=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교 현황(고)_서울특별시교육청.csv")
hs
# Out:
#         시도교육청     지역교육청         지역   정보공시 학교코드                 학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시교육청  서울특별시 송파구  S010000370              가락고등학교      4
# 1    서울특별시교육청  서울특별시교육청  서울특별시 강동구  S010000371              강동고등학교      4
# 2    서울특별시교육청  서울특별시교육청  서울특별시 양천구  S010000372              강서고등학교      4
# 3    서울특별시교육청  서울특별시교육청  서울특별시 강남구  S010000373              개포고등학교      4
# 4    서울특별시교육청  서울특별시교육청  서울특별시 광진구  S010000374     건국대학교사범대학부속고등학교      4
# ..        ...       ...        ...         ...                 ...    ...
# 318  서울특별시교육청  서울특별시교육청  서울특별시 성북구  S010002501    경동고등학교부설방송통신고등학교     11
# 319  서울특별시교육청  서울특별시교육청  서울특별시 종로구  S010002502    경복고등학교부설방송통신고등학교     11
# 320  서울특별시교육청  서울특별시교육청  서울특별시 동작구  S010002503  수도여자고등학교부설방송통신고등학교     11
# 321  서울특별시교육청  서울특별시교육청  서울특별시 동작구  S010002504   영등포고등학교부설방송통신고등학교     11
# 322  서울특별시교육청  서울특별시교육청  서울특별시 강남구  S010002525  경기여자고등학교부설방송통신고등학교     11
#
#     설립구분 제외여부  제외사유  1학년  2학년  3학년  특수학급  순회학급 학급수(계)   학생수(계)  학급당학생수
# ...

# %%
# concat / merge / join
fct_hs.merge(hs, how='outer')
info_hs=info_hs.merge(fct_hs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 # concat / merge / join
#       2 fct_hs.merge(hs, how='outer')
# ----> 3 info_hs=info_hs.merge(fct_hs)
#
# NameError: name 'info_hs' is not defined

# %%
fct_hs=fct_hs.merge(hs, how='outer')

# %%
info_hs=info_hs[['지역','학교명','설립구분','학교특성','위도','경도','남녀공학 구분']]
info_hs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 info_hs=info_hs[['지역','학교명','설립구분','학교특성','위도','경도','남녀공학 구분']]
#       2 info_hs
#
# NameError: name 'info_hs' is not defined

# %%
hs=hs[['지역','학교명','설립구분','학생수(계)']]

# %%
hs
# Out:
#             지역                 학교명 설립구분   학생수(계)
# 0    서울특별시 송파구              가락고등학교   공립   765(0)
# 1    서울특별시 강동구              강동고등학교   사립   672(0)
# 2    서울특별시 양천구              강서고등학교   사립  1014(0)
# 3    서울특별시 강남구              개포고등학교   공립   693(9)
# 4    서울특별시 광진구     건국대학교사범대학부속고등학교   사립   986(0)
# ..         ...                 ...  ...      ...
# 318  서울특별시 성북구    경동고등학교부설방송통신고등학교   공립   224(0)
# 319  서울특별시 종로구    경복고등학교부설방송통신고등학교   공립   336(0)
# 320  서울특별시 동작구  수도여자고등학교부설방송통신고등학교   공립   223(0)
# 321  서울특별시 동작구   영등포고등학교부설방송통신고등학교   공립   213(0)
# 322  서울특별시 강남구  경기여자고등학교부설방송통신고등학교   공립   282(0)
#
# [323 rows x 4 columns]

# %%
info_ms=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교기본정보(중)_서울특별시교육청.csv")
info_ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교      3
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교      3
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교      3
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교      3
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교      3
# ..        ...             ...         ...         ...             ...    ...
# 382  서울특별시교육청    서울특별시남부교육지원청   서울특별시 구로구  S010006401           항동중학교      3
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교      3
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교      3
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교      3
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교      3
#
# ...

# %%
info_ms[info_ms['지역']=='서울특별시 종로구'].설립일
# Out:
# 326    18850509
# 329    19380405
# 330    19200419
# 332    19070908
# 334    18981002
# 336    19661117
# 346    19080601
# 348    19520201
# Name: 설립일, dtype: int64

# %%
info_ms[info_ms['지역']=='서울특별시 동대문구'].설립일
# Out:
# 145    19600518
# 146    19591212
# 147    19471125
# 148    19470624
# 149    19630318
# 154    19691101
# 156    19741227
# 162    19671020
# 163    19671027
# 164    19841208
# 165    19740304
# 166    19080901
# 169    19510830
# 172    19700131
# 173    19691111
# Name: 설립일, dtype: int64

# %%
info_ms.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 학교코드', '학교명', '학교급코드', '설립구분', '학교특성',
#        '분교여부', '설립유형', '주야구분', '개교기념일', '설립일', '법정동코드', '주소내역', '상세주소내역',
#        '우편번호', '학교도로명 우편번호', '학교도로명 주소', '학교도로명 상세주소', '위도', '경도', '전화번호',
#        '팩스번호', '홈페이지 주소', '남녀공학 구분'],
#       dtype='object')

# %%
info_ms.iloc[105]
# Out:
# 시도교육청                         서울특별시교육청
# 지역교육청                   서울특별시강서양천교육지원청
# 지역                           서울특별시 양천구
# 정보공시 학교코드                   S010000996
# 학교명                              양서중학교
# 학교급코드                                3
# 설립구분                                공립
# 학교특성                               NaN
# 분교여부                                 N
# 설립유형                                단설
# 주야구분                                주간
# 개교기념일                         19900506
# 설립일                           19900120
# 법정동코드                       1147010300
# 주소내역                     서울특별시 양천구 신월동
# 상세주소내역                        169-4번지.
# 우편번호                          158829.0
# 학교도로명 우편번호                        7912
# 학교도로명 주소           서울특별시 양천구 남부순환로 380
# 학교도로명 상세주소                 (신월동,양서중학교)
# 위도                           37.532914
# 경도                          126.829502
# 전화번호                      02-6273-8106
# 팩스번호                      02-2603-6676
# ...

# %%
info_hs=pd.read_csv("C:/Users/user/Desktop/school/2023년도_학교기본정보(고)_서울특별시교육청.csv")
info_hs
# Out:
#         시도교육청     지역교육청          지역   정보공시 학교코드              학교명  학교급코드 설립구분  \
# 0    서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010000370           가락고등학교      4   공립
# 1    서울특별시교육청  서울특별시교육청   서울특별시 강동구  S010000371           강동고등학교      4   사립
# 2    서울특별시교육청  서울특별시교육청   서울특별시 양천구  S010000372           강서고등학교      4   사립
# 3    서울특별시교육청  서울특별시교육청   서울특별시 강남구  S010000373           개포고등학교      4   공립
# 4    서울특별시교육청  서울특별시교육청   서울특별시 광진구  S010000374  건국대학교사범대학부속고등학교      4   사립
# ..        ...       ...         ...         ...              ...    ...  ...
# 313  서울특별시교육청  서울특별시교육청  서울특별시 서대문구  S010005591          가재울고등학교      4   공립
# 314  서울특별시교육청  서울특별시교육청   서울특별시 은평구  S010005616           하나고등학교      4   사립
# 315  서울특별시교육청  서울특별시교육청   서울특별시 성동구  S010006381           금호고등학교      4   공립
# 316  서울특별시교육청  서울특별시교육청   서울특별시 성동구  S010006382           도선고등학교      4   공립
# 317  서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010006558      덕수고등학교(일반고)      4   공립
#
# ...

# %%
info_hs['학교특성'].unique()
# Out:
# array(['일반고등학교', '자율고등학교', '특성화고등학교', '특수목적고등학교'], dtype=object)

# %%
info_hs[info_hs['학교특성']=='특수목적고등학교']
# Out:
#         시도교육청     지역교육청          지역   정보공시 학교코드           학교명  학교급코드 설립구분  \
# 90   서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010000461      서울체육고등학교      4   공립
# 195  서울특별시교육청  서울특별시교육청   서울특별시 종로구  S010000569      서울과학고등학교      4   공립
# 196  서울특별시교육청  서울특별시교육청  서울특별시 서대문구  S010000570      한성과학고등학교      4   공립
# 197  서울특별시교육청  서울특별시교육청   서울특별시 광진구  S010000571     대원외국어고등학교      4   사립
# 198  서울특별시교육청  서울특별시교육청   서울특별시 성북구  S010000572     대일외국어고등학교      4   사립
# 199  서울특별시교육청  서울특별시교육청   서울특별시 강서구  S010000573     명덕외국어고등학교      4   사립
# 200  서울특별시교육청  서울특별시교육청   서울특별시 도봉구  S010000574     서울외국어고등학교      4   사립
# 201  서울특별시교육청  서울특별시교육청    서울특별시 중구  S010000575   이화여자외국어고등학교      4   사립
# 202  서울특별시교육청  서울특별시교육청   서울특별시 강동구  S010000576     한영외국어고등학교      4   사립
# 203  서울특별시교육청  서울특별시교육청   서울특별시 강남구  S010000577      서울로봇고등학교      4   공립
# 216  서울특별시교육청  서울특별시교육청   서울특별시 성북구  S010000590  서울도시과학기술고등학교      4   공립
# 220  서울특별시교육청  서울특별시교육청   서울특별시 강남구  S010000594    수도전기공업고등학교      4   사립
# ...

# %%
m = folium.Map(location=[37.566697, 126.978426])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
hs_map= folium.Map(location=[37.566697, 126.978426])

for idx in info_hs.index:
    #print(idx)
    lat=info_hs.loc[idx,"위도"]
    lng=info_hs.loc[idx,"경도"]
    
    fillColor='black'
    
    folium.CircleMarker(
        color=fillColor,
        location=[lat,lng],
        fill=True
    ).add_to(hs_map)

# %%
hs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
info_hs
# Out:
#         시도교육청     지역교육청          지역   정보공시 학교코드              학교명  학교급코드 설립구분  \
# 0    서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010000370           가락고등학교      4   공립
# 1    서울특별시교육청  서울특별시교육청   서울특별시 강동구  S010000371           강동고등학교      4   사립
# 2    서울특별시교육청  서울특별시교육청   서울특별시 양천구  S010000372           강서고등학교      4   사립
# 3    서울특별시교육청  서울특별시교육청   서울특별시 강남구  S010000373           개포고등학교      4   공립
# 4    서울특별시교육청  서울특별시교육청   서울특별시 광진구  S010000374  건국대학교사범대학부속고등학교      4   사립
# ..        ...       ...         ...         ...              ...    ...  ...
# 313  서울특별시교육청  서울특별시교육청  서울특별시 서대문구  S010005591          가재울고등학교      4   공립
# 314  서울특별시교육청  서울특별시교육청   서울특별시 은평구  S010005616           하나고등학교      4   사립
# 315  서울특별시교육청  서울특별시교육청   서울특별시 성동구  S010006381           금호고등학교      4   공립
# 316  서울특별시교육청  서울특별시교육청   서울특별시 성동구  S010006382           도선고등학교      4   공립
# 317  서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010006558      덕수고등학교(일반고)      4   공립
#
# ...

# %%
info_ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교      3
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교      3
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교      3
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교      3
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교      3
# ..        ...             ...         ...         ...             ...    ...
# 382  서울특별시교육청    서울특별시남부교육지원청   서울특별시 구로구  S010006401           항동중학교      3
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교      3
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교      3
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교      3
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교      3
#
# ...

# %%
info_ms[(info_ms['남녀공학 구분']=='남') & (info_ms['체육관 개방여부']=='유')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '체육관 개방여부'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
info_ms_gr=info_ms.groupby(['지역','설립구분','남녀공학 구분', '체육관 개방여부'])

# %%
info_ms_gr.get_group(('서울특별시 마포구','사립','남', '유'))

# %%
info_ms_gr.get_group(('서울특별시 중구','남'))

# %%
info_ms
# Out:
#         시도교육청           지역교육청          지역   정보공시 학교코드             학교명  학교급코드  \
# 0    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000698           개원중학교      3
# 1    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 서초구  S010000700           경원중학교      3
# 2    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000701           구룡중학교      3
# 3    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000702          압구정중학교      3
# 4    서울특별시교육청  서울특별시강남서초교육지원청   서울특별시 강남구  S010000704  단국대학교사범대학부속중학교      3
# ..        ...             ...         ...         ...             ...    ...
# 382  서울특별시교육청    서울특별시남부교육지원청   서울특별시 구로구  S010006401           항동중학교      3
# 383  서울특별시교육청    서울특별시남부교육지원청  서울특별시 영등포구  S010006402           신길중학교      3
# 384  서울특별시교육청  서울특별시강서양천교육지원청   서울특별시 강서구  S010006403         마곡하늬중학교      3
# 385  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 송파구  S010006434          해누리중학교      3
# 386  서울특별시교육청  서울특별시강동송파교육지원청   서울특별시 강동구  S010006545           강빛중학교      3
#
# ...
